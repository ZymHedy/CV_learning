# %%
import torch
import torchvision
import cv2
import matplotlib.pyplot as plt
from torch.utils.data import DataLoader
import torch.nn as nn
import torch.optim as optim

# %%
my_alexnet = torchvision.models.alexnet(pretrained=True)
# Out:
# Downloading: "https://download.pytorch.org/models/alexnet-owt-4df8aa71.pth" to /home/ma-user/.torch/models/alexnet-owt-4df8aa71.pth
# 100%|██████████| 244418560/244418560 [01:12<00:00, 3361645.44it/s]

# %%
import torchvision.transforms as transforms

my_tf = transforms.Compose([
    transforms.Resize((224,224)),
    transforms.ToTensor(),
    transforms.Normalize([0.4914, 0.4822, 0.4465], [0.247, 0.243, 0.261])])
## 同学们可以针对训练时的transform做一些增广，比如随机旋转等

# %%
train_dataset = torchvision.datasets.CIFAR10(root='./cifar10',train=True,transform=my_tf,download=True)
test_dataset = torchvision.datasets.CIFAR10(root='./cifar10',train=False,transform=my_tf,download=True)
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %%
train_dataloader = DataLoader(dataset=train_dataset,batch_size=32,shuffle=True)
test_dataloader = DataLoader(dataset=test_dataset)

# %%
for param in my_alexnet.parameters():
    param.requires_grad=False

# %%
my_alexnet
# Out:
# AlexNet(
#   (features): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(11, 11), stride=(4, 4), padding=(2, 2))
#     (1): ReLU(inplace)
#     (2): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (3): Conv2d(64, 192, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     (4): ReLU(inplace)
#     (5): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (6): Conv2d(192, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (7): ReLU(inplace)
#     (8): Conv2d(384, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (9): ReLU(inplace)
#     (10): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (11): ReLU(inplace)
#     (12): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (classifier): Sequential(
#     (0): Dropout(p=0.5)
#     (1): Linear(in_features=9216, out_features=4096, bias=True)
#     (2): ReLU(inplace)
#     (3): Dropout(p=0.5)
#     (4): Linear(in_features=4096, out_features=4096, bias=True)
#     (5): ReLU(inplace)
#     (6): Linear(in_features=4096, out_features=1000, bias=True)
#   )
# )

# %%
in_f = my_alexnet.classifier[6].in_features
my_alexnet.classifier[6] = nn.Linear(in_f,10)

# %%
learn_rate = 0.001
num_epoches = 1
criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(my_alexnet.classifier[6].parameters(),lr=learn_rate,momentum=0.9)

# %%
device = torch.device('cuda') if torch.cuda.is_available() else torch.device('cpu')

# %%
#train
my_alexnet.to(device)
my_alexnet.train()
for epoch in range(num_epoches):
    print(f"epoch: {epoch+1}")
    for idx,(img,label)in enumerate(train_dataloader):
        images = img.to(device)
        labels = label.to(device)
        output = my_alexnet(images)
        loss = criterion(output,labels)
        loss.backward()
        optimizer.step()
        optimizer.zero_grad()
        if idx%100==0:
            print(f"current loss = {loss.item()}")
# Out:
# epoch: 1
# current loss = 2.541965961456299
# current loss = 0.8652909398078918
# current loss = 1.0931724309921265
# current loss = 0.8530042171478271
# current loss = 0.7725613117218018
# current loss = 0.8463196754455566
# current loss = 0.9321938157081604
# current loss = 0.6227675676345825
# current loss = 0.5539371967315674
# current loss = 0.42793968319892883
# current loss = 1.0118420124053955
# current loss = 0.5574460029602051
# current loss = 0.9021467566490173
# current loss = 0.8032833933830261
# current loss = 0.5987125635147095
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-12-3cab72889e67> in <module>()
#       7         images = img.to(device)
#       8         labels = label.to(device)
# ----> 9         output = my_alexnet(images)
#      10         loss = criterion(output,labels)
#      11         loss.backward()
#
# ~/anaconda3/envs/Pytorch-1.0.0/lib/python3.6/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     487             result = self._slow_forward(*input, **kwargs)
#     488         else:
# --> 489             result = self.forward(*input, **kwargs)
#     490         for hook in self._forward_hooks.values():
#     491             hook_result = hook(self, input, result)
#
# ~/anaconda3/envs/Pytorch-1.0.0/lib/python3.6/site-packages/torchvision/models/alexnet.py in forward(self, x)
#      41
#      42     def forward(self, x):
# ---> 43         x = self.features(x)
#      44         x = x.view(x.size(0), 256 * 6 * 6)
#      45         x = self.classifier(x)
#
# ~/anaconda3/envs/Pytorch-1.0.0/lib/python3.6/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     487             result = self._slow_forward(*input, **kwargs)
#     488         else:
# --> 489             result = self.forward(*input, **kwargs)
#     490         for hook in self._forward_hooks.values():
#     491             hook_result = hook(self, input, result)
#
# ~/anaconda3/envs/Pytorch-1.0.0/lib/python3.6/site-packages/torch/nn/modules/container.py in forward(self, input)
#      90     def forward(self, input):
#      91         for module in self._modules.values():
# ---> 92             input = module(input)
#      93         return input
#      94
#
# ~/anaconda3/envs/Pytorch-1.0.0/lib/python3.6/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     487             result = self._slow_forward(*input, **kwargs)
#     488         else:
# --> 489             result = self.forward(*input, **kwargs)
#     490         for hook in self._forward_hooks.values():
#     491             hook_result = hook(self, input, result)
#
# ~/anaconda3/envs/Pytorch-1.0.0/lib/python3.6/site-packages/torch/nn/modules/conv.py in forward(self, input)
#     318     def forward(self, input):
#     319         return F.conv2d(input, self.weight, self.bias, self.stride,
# --> 320                         self.padding, self.dilation, self.groups)
#     321
#     322
#
# KeyboardInterrupt:

# %%
#eval
my_alexnet.to(device)
my_alexnet.eval()
total,correct = 0 , 0
for img,label in test_dataloader:
    images = img.to(device)
    labels = label.to(device)
    print('label:{}'.format(label))
    output = my_alexnet(images)
#     print(torch.max(output))
    _,idx = torch.max(output.data,1)
    print("idx:{}".format(idx))
    total += labels.size(0)
    correct +=(idx==labels).cpu().sum()

print(f"accuracy:{correct.item()/total}")
# Out:
# label:tensor([3])
# idx:tensor([3], device='cuda:0')
# label:tensor([8])
# idx:tensor([8], device='cuda:0')
# label:tensor([8])
# idx:tensor([8], device='cuda:0')
# label:tensor([0])
# idx:tensor([8], device='cuda:0')
# label:tensor([6])
# idx:tensor([6], device='cuda:0')
# label:tensor([6])
# idx:tensor([6], device='cuda:0')
# label:tensor([1])
# idx:tensor([1], device='cuda:0')
# label:tensor([6])
# idx:tensor([6], device='cuda:0')
# label:tensor([3])
# idx:tensor([3], device='cuda:0')
# label:tensor([1])
# idx:tensor([1], device='cuda:0')
# label:tensor([0])
# idx:tensor([0], device='cuda:0')
# label:tensor([9])
# idx:tensor([9], device='cuda:0')
# label:tensor([5])
# idx:tensor([5], device='cuda:0')
# label:tensor([7])
# idx:tensor([7], device='cuda:0')
# label:tensor([9])
# idx:tensor([9], device='cuda:0')
# label:tensor([8])
# idx:tensor([8], device='cuda:0')
# label:tensor([5])
# idx:tensor([5], device='cuda:0')
# label:tensor([7])
# idx:tensor([7], device='cuda:0')
# label:tensor([8])
# idx:tensor([8], device='cuda:0')
# label:tensor([6])
# idx:tensor([6], device='cuda:0')
# label:tensor([7])
# idx:tensor([7], device='cuda:0')
# label:tensor([0])
# idx:tensor([0], device='cuda:0')
# label:tensor([4])
# idx:tensor([4], device='cuda:0')
# label:tensor([9])
# idx:tensor([9], device='cuda:0')
# label:tensor([5])
# idx:tensor([5], device='cuda:0')
# label:tensor([2])
# idx:tensor([2], device='cuda:0')
# label:tensor([4])
# idx:tensor([4], device='cuda:0')
# label:tensor([0])
# idx:tensor([0], device='cuda:0')
# label:tensor([9])
# idx:tensor([9], device='cuda:0')
# label:tensor([6])
# idx:tensor([6], device='cuda:0')
# label:tensor([6])
# idx:tensor([6], device='cuda:0')
# label:tensor([5])
# idx:tensor([5], device='cuda:0')
# label:tensor([4])
# idx:tensor([4], device='cuda:0')
# label:tensor([5])
# idx:tensor([6], device='cuda:0')
# label:tensor([9])
# idx:tensor([9], device='cuda:0')
# label:tensor([2])
# idx:tensor([2], device='cuda:0')
# label:tensor([4])
# idx:tensor([4], device='cuda:0')
# label:tensor([1])
# idx:tensor([9], device='cuda:0')
# label:tensor([9])
# idx:tensor([9], device='cuda:0')
# label:tensor([5])
# idx:tensor([5], device='cuda:0')
# label:tensor([4])
# idx:tensor([0], device='cuda:0')
# label:tensor([6])
# idx:tensor([6], device='cuda:0')
# label:tensor([5])
# idx:tensor([5], device='cuda:0')
# label:tensor([6])
# idx:tensor([6], device='cuda:0')
# label:tensor([0])
# idx:tensor([0], device='cuda:0')
# label:tensor([9])
# idx:tensor([9], device='cuda:0')
# label:tensor([3])
# idx:tensor([3], device='cuda:0')
# label:tensor([9])
# idx:tensor([9], device='cuda:0')
# label:tensor([7])
# idx:tensor([4], device='cuda:0')
# label:tensor([6])
# idx:tensor([6], device='cuda:0')
# label:tensor([9])
# idx:tensor([9], device='cuda:0')
# label:tensor([8])
# idx:tensor([8], device='cuda:0')
# label:tensor([0])
# idx:tensor([6], device='cuda:0')
# label:tensor([3])
# idx:tensor([3], device='cuda:0')
# label:tensor([8])
# idx:tensor([8], device='cuda:0')
# label:tensor([8])
# idx:tensor([8], device='cuda:0')
# label:tensor([7])
# idx:tensor([7], device='cuda:0')
# label:tensor([7])
# idx:tensor([3], device='cuda:0')
# label:tensor([4])
# idx:tensor([5], device='cuda:0')
# label:tensor([6])
# idx:tensor([5], device='cuda:0')
# label:tensor([7])
# idx:tensor([7], device='cuda:0')
# label:tensor([3])
# idx:tensor([3], device='cuda:0')
# label:tensor([6])
# idx:tensor([6], device='cuda:0')
# label:tensor([3])
# idx:tensor([3], device='cuda:0')
# label:tensor([6])
# idx:tensor([6], device='cuda:0')
# label:tensor([2])
# idx:tensor([2], device='cuda:0')
# label:tensor([1])
# idx:tensor([1], device='cuda:0')
# label:tensor([2])
# idx:tensor([2], device='cuda:0')
# label:tensor([3])
# idx:tensor([3], device='cuda:0')
# label:tensor([7])
# idx:tensor([7], device='cuda:0')
# label:tensor([2])
# idx:tensor([2], device='cuda:0')
# label:tensor([6])
# idx:tensor([3], device='cuda:0')
# label:tensor([8])
# idx:tensor([8], device='cuda:0')
# label:tensor([8])
# idx:tensor([8], device='cuda:0')
# label:tensor([0])
# idx:tensor([9], device='cuda:0')
# label:tensor([2])
# idx:tensor([2], device='cuda:0')
# label:tensor([9])
# idx:tensor([9], device='cuda:0')
# label:tensor([3])
# idx:tensor([3], device='cuda:0')
# label:tensor([3])
# idx:tensor([5], device='cuda:0')
# label:tensor([8])
# idx:tensor([8], device='cuda:0')
# label:tensor([8])
# idx:tensor([8], device='cuda:0')
# label:tensor([1])
# idx:tensor([1], device='cuda:0')
# label:tensor([1])
# idx:tensor([1], device='cuda:0')
# label:tensor([7])
# idx:tensor([7], device='cuda:0')
# label:tensor([2])
# idx:tensor([5], device='cuda:0')
# label:tensor([5])
# idx:tensor([2], device='cuda:0')
# label:tensor([2])
# idx:tensor([2], device='cuda:0')
# label:tensor([7])
# idx:tensor([3], device='cuda:0')
# label:tensor([8])
# idx:tensor([8], device='cuda:0')
# label:tensor([9])
# idx:tensor([9], device='cuda:0')
# label:tensor([0])
# idx:tensor([8], device='cuda:0')
# label:tensor([3])
# idx:tensor([3], device='cuda:0')
# label:tensor([8])
# idx:tensor([8], device='cuda:0')
# label:tensor([6])
# idx:tensor([6], device='cuda:0')
# label:tensor([4])
# idx:tensor([4], device='cuda:0')
# label:tensor([6])
# idx:tensor([6], device='cuda:0')
# label:tensor([6])
# idx:tensor([6], device='cuda:0')
# label:tensor([0])
# idx:tensor([0], device='cuda:0')
# label:tensor([0])
# idx:tensor([0], device='cuda:0')
# label:tensor([7])
# idx:tensor([7], device='cuda:0')
# label:tensor([4])
# idx:tensor([4], device='cuda:0')
# label:tensor([5])
# idx:tensor([5], device='cuda:0')
# label:tensor([6])
# idx:tensor([6], device='cuda:0')
# label:tensor([3])
# idx:tensor([3], device='cuda:0')
# label:tensor([1])
# idx:tensor([1], device='cuda:0')
# label:tensor([1])
# idx:tensor([1], device='cuda:0')
# label:tensor([3])
# idx:tensor([2], device='cuda:0')
# label:tensor([6])
# idx:tensor([6], device='cuda:0')
# label:tensor([8])
# idx:tensor([8], device='cuda:0')
# label:tensor([7])
# idx:tensor([7], device='cuda:0')
# label:tensor([4])
# idx:tensor([4], device='cuda:0')
# label:tensor([0])
# idx:tensor([0], device='cuda:0')
# label:tensor([6])
# idx:tensor([6], device='cuda:0')
# label:tensor([2])
# idx:tensor([2], device='cuda:0')
# label:tensor([1])
# idx:tensor([1], device='cuda:0')
# label:tensor([3])
# idx:tensor([3], device='cuda:0')
# label:tensor([0])
# idx:tensor([0], device='cuda:0')
# label:tensor([4])
# idx:tensor([7], device='cuda:0')
# label:tensor([2])
# idx:tensor([6], device='cuda:0')
# label:tensor([7])
# idx:tensor([5], device='cuda:0')
# label:tensor([8])
# idx:tensor([8], device='cuda:0')
# label:tensor([3])
# idx:tensor([3], device='cuda:0')
# label:tensor([1])
# idx:tensor([1], device='cuda:0')
# label:tensor([2])
# idx:tensor([2], device='cuda:0')
# label:tensor([8])
# idx:tensor([8], device='cuda:0')
# label:tensor([0])
# idx:tensor([2], device='cuda:0')
# label:tensor([8])
# idx:tensor([8], device='cuda:0')
# label:tensor([3])
# idx:tensor([3], device='cuda:0')
# label:tensor([5])
# idx:tensor([3], device='cuda:0')
# label:tensor([2])
# idx:tensor([2], device='cuda:0')
# label:tensor([4])
# idx:tensor([4], device='cuda:0')
# label:tensor([1])
# idx:tensor([1], device='cuda:0')
# label:tensor([8])
# idx:tensor([8], device='cuda:0')
# label:tensor([9])
# idx:tensor([9], device='cuda:0')
# label:tensor([1])
# idx:tensor([9], device='cuda:0')
# label:tensor([2])
# idx:tensor([2], device='cuda:0')
# label:tensor([9])
# idx:tensor([9], device='cuda:0')
# label:tensor([7])
# idx:tensor([7], device='cuda:0')
# label:tensor([2])
# idx:tensor([2], device='cuda:0')
# label:tensor([9])
# idx:tensor([8], device='cuda:0')
# label:tensor([6])
# idx:tensor([6], device='cuda:0')
# label:tensor([5])
# idx:tensor([5], device='cuda:0')
# label:tensor([6])
# idx:tensor([6], device='cuda:0')
# label:tensor([3])
# idx:tensor([3], device='cuda:0')
# label:tensor([8])
# idx:tensor([8], device='cuda:0')
# label:tensor([7])
# idx:tensor([2], device='cuda:0')
# label:tensor([6])
# idx:tensor([6], device='cuda:0')
# label:tensor([2])
# idx:tensor([5], device='cuda:0')
# label:tensor([5])
# idx:tensor([5], device='cuda:0')
# label:tensor([2])
# idx:tensor([3], device='cuda:0')
# label:tensor([8])
# idx:tensor([0], device='cuda:0')
# label:tensor([9])
# idx:tensor([9], device='cuda:0')
# label:tensor([6])
# idx:tensor([6], device='cuda:0')
# label:tensor([0])
# idx:tensor([7], device='cuda:0')
# label:tensor([0])
# idx:tensor([0], device='cuda:0')
# label:tensor([5])
# idx:tensor([5], device='cuda:0')
# label:tensor([2])
# idx:tensor([3], device='cuda:0')
# label:tensor([9])
# idx:tensor([9], device='cuda:0')
# label:tensor([5])
# idx:tensor([5], device='cuda:0')
# label:tensor([4])
# idx:tensor([4], device='cuda:0')
# label:tensor([2])
# idx:tensor([2], device='cuda:0')
# label:tensor([1])
# idx:tensor([1], device='cuda:0')
# label:tensor([6])
# idx:tensor([3], device='cuda:0')
# label:tensor([6])
# idx:tensor([6], device='cuda:0')
# label:tensor([8])
# idx:tensor([0], device='cuda:0')
# label:tensor([4])
# idx:tensor([4], device='cuda:0')
# label:tensor([8])
# idx:tensor([8], device='cuda:0')
# label:tensor([4])
# idx:tensor([4], device='cuda:0')
# label:tensor([5])
# idx:tensor([5], device='cuda:0')
# label:tensor([0])
# idx:tensor([0], device='cuda:0')
# label:tensor([9])
# idx:tensor([9], device='cuda:0')
# label:tensor([9])
# idx:tensor([9], device='cuda:0')
# label:tensor([9])
# idx:tensor([9], device='cuda:0')
# label:tensor([8])
# idx:tensor([8], device='cuda:0')
# label:tensor([9])
# idx:tensor([9], device='cuda:0')
# label:tensor([9])
# idx:tensor([9], device='cuda:0')
# label:tensor([3])
# idx:tensor([3], device='cuda:0')
# label:tensor([7])
# idx:tensor([7], device='cuda:0')
# label:tensor([5])
# idx:tensor([5], device='cuda:0')
# label:tensor([0])
# idx:tensor([0], device='cuda:0')
# label:tensor([0])
# idx:tensor([0], device='cuda:0')
# label:tensor([5])
# idx:tensor([5], device='cuda:0')
# label:tensor([2])
# idx:tensor([2], device='cuda:0')
# label:tensor([2])
# idx:tensor([6], device='cuda:0')
# label:tensor([3])
# idx:tensor([3], device='cuda:0')
# label:tensor([8])
# idx:tensor([8], device='cuda:0')
# label:tensor([6])
# idx:tensor([6], device='cuda:0')
# label:tensor([3])
# idx:tensor([3], device='cuda:0')
# label:tensor([4])
# idx:tensor([3], device='cuda:0')
# label:tensor([0])
# idx:tensor([8], device='cuda:0')
# label:tensor([5])
# idx:tensor([5], device='cuda:0')
# label:tensor([8])
# idx:tensor([8], device='cuda:0')
# label:tensor([0])
# idx:tensor([0], device='cuda:0')
# label:tensor([1])
# idx:tensor([1], device='cuda:0')
# label:tensor([7])
# idx:tensor([6], device='cuda:0')
# label:tensor([2])
# idx:tensor([2], device='cuda:0')
# label:tensor([8])
# idx:tensor([8], device='cuda:0')
# label:tensor([8])
# idx:tensor([8], device='cuda:0')
# label:tensor([7])
# idx:tensor([7], device='cuda:0')
# label:tensor([8])
# idx:tensor([8], device='cuda:0')
# label:tensor([5])
# idx:tensor([5], device='cuda:0')
# label:tensor([1])
# idx:tensor([0], device='cuda:0')
# label:tensor([8])
# idx:tensor([8], device='cuda:0')
# label:tensor([7])
# idx:tensor([9], device='cuda:0')
# label:tensor([1])
# idx:tensor([1], device='cuda:0')
# label:tensor([3])
# idx:tensor([3], device='cuda:0')
# label:tensor([0])
# idx:tensor([0], device='cuda:0')
# label:tensor([5])
# idx:tensor([4], device='cuda:0')
# label:tensor([7])
# idx:tensor([7], device='cuda:0')
# label:tensor([9])
# idx:tensor([9], device='cuda:0')
# label:tensor([7])
# idx:tensor([5], device='cuda:0')
# label:tensor([4])
# idx:tensor([8], device='cuda:0')
# label:tensor([5])
# idx:tensor([5], device='cuda:0')
# label:tensor([9])
# idx:tensor([9], device='cuda:0')
# label:tensor([8])
# idx:tensor([8], device='cuda:0')
# label:tensor([0])
# idx:tensor([0], device='cuda:0')
# label:tensor([7])
# idx:tensor([7], device='cuda:0')
# label:tensor([9])
# idx:tensor([9], device='cuda:0')
# label:tensor([8])
# idx:tensor([8], device='cuda:0')
# label:tensor([2])
# idx:tensor([2], device='cuda:0')
# label:tensor([7])
# idx:tensor([7], device='cuda:0')
# label:tensor([6])
# idx:tensor([5], device='cuda:0')
# label:tensor([9])
# idx:tensor([9], device='cuda:0')
# label:tensor([4])
# idx:tensor([3], device='cuda:0')
# label:tensor([3])
# idx:tensor([3], device='cuda:0')
# label:tensor([9])
# idx:tensor([9], device='cuda:0')
# label:tensor([6])
# idx:tensor([3], device='cuda:0')
# label:tensor([4])
# idx:tensor([4], device='cuda:0')
# label:tensor([7])
# idx:tensor([4], device='cuda:0')
# label:tensor([6])
# idx:tensor([2], device='cuda:0')
# label:tensor([5])
# idx:tensor([5], device='cuda:0')
# label:tensor([1])
# idx:tensor([9], device='cuda:0')
# label:tensor([5])
# idx:tensor([3], device='cuda:0')
# label:tensor([8])
# idx:tensor([1], device='cuda:0')
# label:tensor([8])
# idx:tensor([8], device='cuda:0')
# label:tensor([0])
# idx:tensor([0], device='cuda:0')
# label:tensor([4])
# idx:tensor([4], device='cuda:0')
# label:tensor([0])
# idx:tensor([9], device='cuda:0')
# label:tensor([5])
# idx:tensor([5], device='cuda:0')
# label:tensor([5])
# idx:tensor([5], device='cuda:0')
# label:tensor([1])
# idx:tensor([1], device='cuda:0')
# label:tensor([1])
# idx:tensor([9], device='cuda:0')
# label:tensor([8])
# idx:tensor([1], device='cuda:0')
# label:tensor([9])
# idx:tensor([9], device='cuda:0')
# label:tensor([0])
# idx:tensor([0], device='cuda:0')
# label:tensor([3])
# idx:tensor([3], device='cuda:0')
# label:tensor([1])
# idx:tensor([1], device='cuda:0')
# label:tensor([9])
# idx:tensor([8], device='cuda:0')
# label:tensor([2])
# idx:tensor([9], device='cuda:0')
# label:tensor([2])
# idx:tensor([2], device='cuda:0')
# label:tensor([5])
# idx:tensor([5], device='cuda:0')
# label:tensor([3])
# idx:tensor([3], device='cuda:0')
# label:tensor([9])
# idx:tensor([9], device='cuda:0')
# label:tensor([9])
# idx:tensor([9], device='cuda:0')
# label:tensor([4])
# idx:tensor([4], device='cuda:0')
# label:tensor([0])
# idx:tensor([3], device='cuda:0')
# label:tensor([3])
# idx:tensor([3], device='cuda:0')
# label:tensor([0])
# idx:tensor([0], device='cuda:0')
# label:tensor([0])
# idx:tensor([8], device='cuda:0')
# label:tensor([9])
# idx:tensor([9], device='cuda:0')
# label:tensor([8])
# idx:tensor([9], device='cuda:0')
# label:tensor([1])
# idx:tensor([1], device='cuda:0')
# label:tensor([5])
# idx:tensor([2], device='cuda:0')
# label:tensor([7])
# idx:tensor([3], device='cuda:0')
# label:tensor([0])
# idx:tensor([8], device='cuda:0')
# label:tensor([8])
# idx:tensor([8], device='cuda:0')
# label:tensor([2])
# idx:tensor([2], device='cuda:0')
# label:tensor([4])
# idx:tensor([4], device='cuda:0')
# label:tensor([7])
# idx:tensor([7], device='cuda:0')
# label:tensor([0])
# idx:tensor([2], device='cuda:0')
# label:tensor([2])
# idx:tensor([2], device='cuda:0')
# label:tensor([3])
# idx:tensor([3], device='cuda:0')
# label:tensor([6])
# idx:tensor([6], device='cuda:0')
# label:tensor([3])
# idx:tensor([3], device='cuda:0')
# label:tensor([8])
# idx:tensor([8], device='cuda:0')
# label:tensor([5])
# idx:tensor([3], device='cuda:0')
# label:tensor([0])
# idx:tensor([0], device='cuda:0')
# label:tensor([3])
# idx:tensor([3], device='cuda:0')
# label:tensor([4])
# idx:tensor([4], device='cuda:0')
# label:tensor([3])
# idx:tensor([5], device='cuda:0')
# label:tensor([9])
# idx:tensor([9], device='cuda:0')
# label:tensor([0])
# idx:tensor([6], device='cuda:0')
# label:tensor([6])
# idx:tensor([6], device='cuda:0')
# label:tensor([1])
# idx:tensor([1], device='cuda:0')
# label:tensor([0])
# idx:tensor([9], device='cuda:0')
# label:tensor([9])
# idx:tensor([9], device='cuda:0')
# label:tensor([1])
# idx:tensor([1], device='cuda:0')
# label:tensor([0])
# idx:tensor([8], device='cuda:0')
# label:tensor([7])
# idx:tensor([7], device='cuda:0')
# label:tensor([9])
# idx:tensor([9], device='cuda:0')
# label:tensor([1])
# idx:tensor([1], device='cuda:0')
# label:tensor([2])
# idx:tensor([2], device='cuda:0')
# label:tensor([6])
# idx:tensor([6], device='cuda:0')
# label:tensor([9])
# idx:tensor([9], device='cuda:0')
# label:tensor([3])
# idx:tensor([3], device='cuda:0')
# label:tensor([4])
# idx:tensor([2], device='cuda:0')
# label:tensor([6])
# idx:tensor([6], device='cuda:0')
# label:tensor([0])
# idx:tensor([0], device='cuda:0')
# label:tensor([0])
# idx:tensor([0], device='cuda:0')
# label:tensor([6])
# idx:tensor([6], device='cuda:0')
# label:tensor([6])
# idx:tensor([6], device='cuda:0')
# label:tensor([6])
# idx:tensor([6], device='cuda:0')
# label:tensor([3])
# idx:tensor([5], device='cuda:0')
# label:tensor([2])
# idx:tensor([2], device='cuda:0')
# label:tensor([6])
# idx:tensor([6], device='cuda:0')
# label:tensor([1])
# idx:tensor([0], device='cuda:0')
# label:tensor([8])
# idx:tensor([9], device='cuda:0')
# label:tensor([2])
# idx:tensor([2], device='cuda:0')
# label:tensor([1])
# idx:tensor([1], device='cuda:0')
# label:tensor([6])
# idx:tensor([2], device='cuda:0')
# label:tensor([8])
# idx:tensor([8], device='cuda:0')
# label:tensor([6])
# idx:tensor([6], device='cuda:0')
# label:tensor([8])
# idx:tensor([8], device='cuda:0')
# label:tensor([0])
# idx:tensor([3], device='cuda:0')
# label:tensor([4])
# idx:tensor([4], device='cuda:0')
# label:tensor([0])
# idx:tensor([0], device='cuda:0')
# label:tensor([7])
# idx:tensor([2], device='cuda:0')
# label:tensor([7])
# idx:tensor([7], device='cuda:0')
# label:tensor([5])
# idx:tensor([5], device='cuda:0')
# label:tensor([5])
# idx:tensor([5], device='cuda:0')
# label:tensor([3])
# idx:tensor([3], device='cuda:0')
# label:tensor([5])
# idx:tensor([3], device='cuda:0')
# label:tensor([2])
# idx:tensor([2], device='cuda:0')
# label:tensor([3])
# idx:tensor([3], device='cuda:0')
# label:tensor([4])
# idx:tensor([7], device='cuda:0')
# label:tensor([1])
# idx:tensor([1], device='cuda:0')
# label:tensor([7])
# idx:tensor([4], device='cuda:0')
# label:tensor([5])
# idx:tensor([5], device='cuda:0')
# label:tensor([4])
# idx:tensor([4], device='cuda:0')
# label:tensor([6])
# idx:tensor([6], device='cuda:0')
# label:tensor([1])
# idx:tensor([1], device='cuda:0')
# label:tensor([9])
# idx:tensor([9], device='cuda:0')
# label:tensor([3])
# idx:tensor([3], device='cuda:0')
# label:tensor([6])
# idx:tensor([6], device='cuda:0')
# label:tensor([6])
# idx:tensor([6], device='cuda:0')
# label:tensor([9])
# idx:tensor([9], device='cuda:0')
# label:tensor([3])
# idx:tensor([3], device='cuda:0')
# label:tensor([8])
# idx:tensor([8], device='cuda:0')
# label:tensor([0])
# idx:tensor([0], device='cuda:0')
# label:tensor([7])
# idx:tensor([2], device='cuda:0')
# label:tensor([2])
# idx:tensor([2], device='cuda:0')
# label:tensor([6])
# idx:tensor([6], device='cuda:0')
# label:tensor([2])
# idx:tensor([2], device='cuda:0')
# label:tensor([5])
# idx:tensor([5], device='cuda:0')
# label:tensor([8])
# idx:tensor([8], device='cuda:0')
# label:tensor([5])
# idx:tensor([5], device='cuda:0')
# label:tensor([4])
# idx:tensor([3], device='cuda:0')
# label:tensor([6])
# idx:tensor([6], device='cuda:0')
# label:tensor([8])
# idx:tensor([8], device='cuda:0')
# label:tensor([9])
# idx:tensor([9], device='cuda:0')
# label:tensor([9])
# idx:tensor([9], device='cuda:0')
# label:tensor([1])
# idx:tensor([1], device='cuda:0')
# label:tensor([0])
# idx:tensor([8], device='cuda:0')
# label:tensor([2])
# idx:tensor([2], device='cuda:0')
# label:tensor([2])
# idx:tensor([6], device='cuda:0')
# label:tensor([7])
# idx:tensor([3], device='cuda:0')
# label:tensor([3])
# idx:tensor([3], device='cuda:0')
# label:tensor([2])
# idx:tensor([2], device='cuda:0')
# label:tensor([8])
# idx:tensor([8], device='cuda:0')
# label:tensor([0])
# idx:tensor([0], device='cuda:0')
# label:tensor([9])
# idx:tensor([9], device='cuda:0')
# label:tensor([5])
# idx:tensor([5], device='cuda:0')
# label:tensor([8])
# idx:tensor([8], device='cuda:0')
# label:tensor([1])
# idx:tensor([1], device='cuda:0')
# label:tensor([9])
# idx:tensor([9], device='cuda:0')
# label:tensor([4])
# idx:tensor([7], device='cuda:0')
# label:tensor([1])
# idx:tensor([1], device='cuda:0')
# label:tensor([3])
# idx:tensor([5], device='cuda:0')
# label:tensor([8])
# idx:tensor([8], device='cuda:0')
# label:tensor([1])
# idx:tensor([1], device='cuda:0')
# label:tensor([4])
# idx:tensor([4], device='cuda:0')
# label:tensor([7])
# idx:tensor([7], device='cuda:0')
# label:tensor([9])
# idx:tensor([9], device='cuda:0')
# label:tensor([4])
# idx:tensor([4], device='cuda:0')
# label:tensor([2])
# idx:tensor([2], device='cuda:0')
# label:tensor([7])
# idx:tensor([7], device='cuda:0')
# label:tensor([0])
# idx:tensor([0], device='cuda:0')
# label:tensor([7])
# idx:tensor([7], device='cuda:0')
# label:tensor([0])
# idx:tensor([8], device='cuda:0')
# label:tensor([6])
# idx:tensor([6], device='cuda:0')
# label:tensor([6])
# idx:tensor([6], device='cuda:0')
# label:tensor([9])
# idx:tensor([9], device='cuda:0')
# label:tensor([0])
# idx:tensor([6], device='cuda:0')
# label:tensor([9])
# idx:tensor([9], device='cuda:0')
# label:tensor([2])
# idx:tensor([2], device='cuda:0')
# label:tensor([8])
# idx:tensor([0], device='cuda:0')
# label:tensor([7])
# idx:tensor([7], device='cuda:0')
# label:tensor([2])
# idx:tensor([2], device='cuda:0')
# label:tensor([2])
# idx:tensor([2], device='cuda:0')
# label:tensor([5])
# idx:tensor([5], device='cuda:0')
# label:tensor([1])
# idx:tensor([1], device='cuda:0')
# label:tensor([2])
# idx:tensor([2], device='cuda:0')
# label:tensor([6])
# idx:tensor([6], device='cuda:0')
# label:tensor([2])
# idx:tensor([2], device='cuda:0')
# label:tensor([9])
# idx:tensor([9], device='cuda:0')
# label:tensor([6])
# idx:tensor([6], device='cuda:0')
# label:tensor([2])
# idx:tensor([2], device='cuda:0')
# label:tensor([3])
# idx:tensor([3], device='cuda:0')
# label:tensor([0])
# idx:tensor([1], device='cuda:0')
# label:tensor([3])
# idx:tensor([3], device='cuda:0')
# label:tensor([9])
# idx:tensor([9], device='cuda:0')
# label:tensor([8])
# idx:tensor([1], device='cuda:0')
# label:tensor([7])
# idx:tensor([7], device='cuda:0')
# label:tensor([8])
# idx:tensor([8], device='cuda:0')
# label:tensor([8])
# idx:tensor([8], device='cuda:0')
# label:tensor([4])
# idx:tensor([6], device='cuda:0')
# label:tensor([0])
# idx:tensor([0], device='cuda:0')
# label:tensor([1])
# idx:tensor([1], device='cuda:0')
# label:tensor([8])
# idx:tensor([8], device='cuda:0')
# label:tensor([2])
# idx:tensor([5], device='cuda:0')
# label:tensor([7])
# idx:tensor([2], device='cuda:0')
# label:tensor([9])
# idx:tensor([8], device='cuda:0')
# label:tensor([3])
# idx:tensor([3], device='cuda:0')
# label:tensor([6])
# idx:tensor([6], device='cuda:0')
# label:tensor([1])
# idx:tensor([1], device='cuda:0')
# label:tensor([9])
# idx:tensor([9], device='cuda:0')
# label:tensor([0])
# idx:tensor([3], device='cuda:0')
# label:tensor([7])
# idx:tensor([7], device='cuda:0')
# label:tensor([3])
# idx:tensor([2], device='cuda:0')
# label:tensor([7])
# idx:tensor([7], device='cuda:0')
# label:tensor([4])
# idx:tensor([4], device='cuda:0')
# label:tensor([5])
# idx:tensor([5], device='cuda:0')
# label:tensor([0])
# idx:tensor([0], device='cuda:0')
# label:tensor([0])
# idx:tensor([3], device='cuda:0')
# label:tensor([2])
# idx:tensor([2], device='cuda:0')
# label:tensor([9])
# idx:tensor([9], device='cuda:0')
# label:tensor([3])
# idx:tensor([6], device='cuda:0')
# label:tensor([4])
# idx:tensor([4], device='cuda:0')
# label:tensor([0])
# idx:tensor([9], device='cuda:0')
# label:tensor([6])
# idx:tensor([3], device='cuda:0')
# label:tensor([2])
# idx:tensor([2], device='cuda:0')
# label:tensor([5])
# idx:tensor([5], device='cuda:0')
# label:tensor([3])
# idx:tensor([3], device='cuda:0')
# label:tensor([7])
# idx:tensor([7], device='cuda:0')
# label:tensor([3])
# idx:tensor([5], device='cuda:0')
# label:tensor([7])
# idx:tensor([7], device='cuda:0')
# label:tensor([2])
# idx:tensor([2], device='cuda:0')
# label:tensor([5])
# idx:tensor([4], device='cuda:0')
# label:tensor([3])
# idx:tensor([5], device='cuda:0')
# label:tensor([1])
# idx:tensor([1], device='cuda:0')
# label:tensor([1])
# idx:tensor([1], device='cuda:0')
# label:tensor([4])
# idx:tensor([2], device='cuda:0')
# label:tensor([9])
# idx:tensor([9], device='cuda:0')
# label:tensor([9])
# idx:tensor([9], device='cuda:0')
# label:tensor([5])
# idx:tensor([5], device='cuda:0')
# label:tensor([7])
# idx:tensor([7], device='cuda:0')
# label:tensor([5])
# idx:tensor([5], device='cuda:0')
# label:tensor([0])
# idx:tensor([0], device='cuda:0')
# label:tensor([2])
# idx:tensor([2], device='cuda:0')
# label:tensor([2])
# idx:tensor([2], device='cuda:0')
# label:tensor([2])
# idx:tensor([3], device='cuda:0')
# label:tensor([9])
# idx:tensor([9], device='cuda:0')
# label:tensor([7])
# idx:tensor([3], device='cuda:0')
# label:tensor([3])
# idx:tensor([3], device='cuda:0')
# label:tensor([9])
# idx:tensor([9], device='cuda:0')
# label:tensor([4])
# idx:tensor([4], device='cuda:0')
# label:tensor([3])
# idx:tensor([4], device='cuda:0')
# label:tensor([5])
# idx:tensor([5], device='cuda:0')
# label:tensor([4])
# idx:tensor([3], device='cuda:0')
# label:tensor([6])
# idx:tensor([6], device='cuda:0')
# label:tensor([5])
# idx:tensor([5], device='cuda:0')
# label:tensor([6])
# idx:tensor([6], device='cuda:0')
# label:tensor([1])
# idx:tensor([1], device='cuda:0')
# label:tensor([4])
# idx:tensor([4], device='cuda:0')
# label:tensor([3])
# idx:tensor([3], device='cuda:0')
# label:tensor([4])
# idx:tensor([4], device='cuda:0')
# label:tensor([4])
# idx:tensor([4], device='cuda:0')
# label:tensor([3])
# idx:tensor([3], device='cuda:0')
# label:tensor([7])
# idx:tensor([6], device='cuda:0')
# label:tensor([8])
# idx:tensor([8], device='cuda:0')
# label:tensor([3])
# idx:tensor([3], device='cuda:0')
# label:tensor([7])
# idx:tensor([7], device='cuda:0')
# label:tensor([8])
# idx:tensor([8], device='cuda:0')
# label:tensor([0])
# idx:tensor([8], device='cuda:0')
# label:tensor([5])
# idx:tensor([5], device='cuda:0')
# label:tensor([7])
# idx:tensor([7], device='cuda:0')
# label:tensor([6])
# idx:tensor([6], device='cuda:0')
# label:tensor([0])
# idx:tensor([0], device='cuda:0')
# label:tensor([5])
# idx:tensor([5], device='cuda:0')
# label:tensor([4])
# idx:tensor([4], device='cuda:0')
# label:tensor([8])
# idx:tensor([1], device='cuda:0')
# label:tensor([6])
# idx:tensor([6], device='cuda:0')
# label:tensor([8])
# idx:tensor([8], device='cuda:0')
# label:tensor([5])
# idx:tensor([3], device='cuda:0')
# label:tensor([5])
# idx:tensor([5], device='cuda:0')
# label:tensor([9])
# idx:tensor([9], device='cuda:0')
# label:tensor([9])
# idx:tensor([9], device='cuda:0')
# label:tensor([9])
# idx:tensor([9], device='cuda:0')
# label:tensor([5])
# idx:tensor([4], device='cuda:0')
# label:tensor([0])
# idx:tensor([0], device='cuda:0')
# label:tensor([1])
# idx:tensor([1], device='cuda:0')
# label:tensor([0])
# idx:tensor([9], device='cuda:0')
# label:tensor([8])
# idx:tensor([8], device='cuda:0')
# label:tensor([1])
# idx:tensor([1], device='cuda:0')
# label:tensor([1])
# idx:tensor([1], device='cuda:0')
# label:tensor([8])
# idx:tensor([8], device='cuda:0')
# label:tensor([0])
# idx:tensor([0], device='cuda:0')
# label:tensor([2])
# idx:tensor([2], device='cuda:0')
# label:tensor([2])
# idx:tensor([2], device='cuda:0')
# label:tensor([0])
# idx:tensor([0], device='cuda:0')
# label:tensor([4])
# idx:tensor([6], device='cuda:0')
# label:tensor([6])
# idx:tensor([6], device='cuda:0')
# label:tensor([5])
# idx:tensor([5], device='cuda:0')
# label:tensor([4])
# idx:tensor([4], device='cuda:0')
# label:tensor([9])
# idx:tensor([9], device='cuda:0')
# label:tensor([4])
# idx:tensor([4], device='cuda:0')
# label:tensor([7])
# idx:tensor([7], device='cuda:0')
# label:tensor([9])
# idx:tensor([9], device='cuda:0')
# label:tensor([9])
# idx:tensor([9], device='cuda:0')
# label:tensor([4])
# idx:tensor([4], device='cuda:0')
# label:tensor([5])
# idx:tensor([5], device='cuda:0')
# label:tensor([6])
# idx:tensor([6], device='cuda:0')
# label:tensor([6])
# idx:tensor([6], device='cuda:0')
# label:tensor([1])
# idx:tensor([1], device='cuda:0')
# label:tensor([5])
# idx:tensor([5], device='cuda:0')
# label:tensor([3])
# idx:tensor([3], device='cuda:0')
# label:tensor([8])
# idx:tensor([8], device='cuda:0')
# label:tensor([9])
# idx:tensor([9], device='cuda:0')
# label:tensor([5])
# idx:tensor([3], device='cuda:0')
# label:tensor([8])
# idx:tensor([1], device='cuda:0')
# label:tensor([5])
# idx:tensor([5], device='cuda:0')
# label:tensor([7])
# idx:tensor([7], device='cuda:0')
# label:tensor([0])
# idx:tensor([0], device='cuda:0')
# label:tensor([7])
# idx:tensor([7], device='cuda:0')
# label:tensor([0])
# idx:tensor([0], device='cuda:0')
# label:tensor([5])
# idx:tensor([5], device='cuda:0')
# label:tensor([0])
# idx:tensor([9], device='cuda:0')
# label:tensor([0])
# idx:tensor([0], device='cuda:0')
# label:tensor([4])
# idx:tensor([4], device='cuda:0')
# label:tensor([6])
# idx:tensor([6], device='cuda:0')
# label:tensor([9])
# idx:tensor([9], device='cuda:0')
# label:tensor([0])
# idx:tensor([3], device='cuda:0')
# label:tensor([9])
# idx:tensor([9], device='cuda:0')
# label:tensor([5])
# idx:tensor([5], device='cuda:0')
# label:tensor([6])
# idx:tensor([6], device='cuda:0')
# label:tensor([6])
# idx:tensor([6], device='cuda:0')
# label:tensor([6])
# idx:tensor([6], device='cuda:0')
# label:tensor([2])
# idx:tensor([6], device='cuda:0')
# label:tensor([9])
# idx:tensor([9], device='cuda:0')
# label:tensor([0])
# idx:tensor([9], device='cuda:0')
# label:tensor([1])
# idx:tensor([1], device='cuda:0')
# label:tensor([7])
# idx:tensor([7], device='cuda:0')
# label:tensor([6])
# idx:tensor([6], device='cuda:0')
# label:tensor([7])
# idx:tensor([7], device='cuda:0')
# label:tensor([5])
# idx:tensor([5], device='cuda:0')
# label:tensor([9])
# idx:tensor([9], device='cuda:0')
# label:tensor([1])
# idx:tensor([1], device='cuda:0')
# label:tensor([6])
# idx:tensor([6], device='cuda:0')
# label:tensor([2])
# idx:tensor([2], device='cuda:0')
# label:tensor([5])
# idx:tensor([5], device='cuda:0')
# label:tensor([5])
# idx:tensor([5], device='cuda:0')
# label:tensor([5])
# idx:tensor([5], device='cuda:0')
# label:tensor([8])
# idx:tensor([8], device='cuda:0')
# label:tensor([5])
# idx:tensor([5], device='cuda:0')
# label:tensor([9])
# idx:tensor([9], device='cuda:0')
# label:tensor([4])
# idx:tensor([4], device='cuda:0')
# label:tensor([6])
# idx:tensor([6], device='cuda:0')
# label:tensor([4])
# idx:tensor([4], device='cuda:0')
# label:tensor([3])
# idx:tensor([3], device='cuda:0')
# label:tensor([2])
# idx:tensor([2], device='cuda:0')
# label:tensor([0])
# idx:tensor([0], device='cuda:0')
# label:tensor([7])
# idx:tensor([7], device='cuda:0')
# label:tensor([6])
# idx:tensor([6], device='cuda:0')
# label:tensor([2])
# idx:tensor([2], device='cuda:0')
# label:tensor([2])
# idx:tensor([2], device='cuda:0')
# label:tensor([3])
# idx:tensor([5], device='cuda:0')
# label:tensor([9])
# idx:tensor([9], device='cuda:0')
# label:tensor([7])
# idx:tensor([7], device='cuda:0')
# label:tensor([9])
# idx:tensor([9], device='cuda:0')
# label:tensor([2])
# idx:tensor([2], device='cuda:0')
# label:tensor([6])
# idx:tensor([6], device='cuda:0')
# label:tensor([7])
# idx:tensor([7], device='cuda:0')
# label:tensor([1])
# idx:tensor([1], device='cuda:0')
# label:tensor([3])
# idx:tensor([3], device='cuda:0')
# label:tensor([6])
# idx:tensor([6], device='cuda:0')
# label:tensor([6])
# idx:tensor([6], device='cuda:0')
# label:tensor([8])
# idx:tensor([8], device='cuda:0')
# label:tensor([9])
# idx:tensor([9], device='cuda:0')
# label:tensor([7])
# idx:tensor([7], device='cuda:0')
# label:tensor([5])
# idx:tensor([5], device='cuda:0')
# label:tensor([4])
# idx:tensor([4], device='cuda:0')
# label:tensor([0])
# idx:tensor([8], device='cuda:0')
# label:tensor([8])
# idx:tensor([8], device='cuda:0')
# label:tensor([4])
# idx:tensor([4], device='cuda:0')
# label:tensor([0])
# idx:tensor([0], device='cuda:0')
# label:tensor([9])
# idx:tensor([9], device='cuda:0')
# label:tensor([3])
# idx:tensor([3], device='cuda:0')
# label:tensor([4])
# idx:tensor([4], device='cuda:0')
# label:tensor([8])
# idx:tensor([8], device='cuda:0')
# label:tensor([9])
# idx:tensor([9], device='cuda:0')
# label:tensor([6])
# idx:tensor([6], device='cuda:0')
# label:tensor([9])
# idx:tensor([9], device='cuda:0')
# label:tensor([2])
# idx:tensor([2], device='cuda:0')
# label:tensor([6])
# idx:tensor([6], device='cuda:0')
# label:tensor([1])
# idx:tensor([1], device='cuda:0')
# label:tensor([4])
# idx:tensor([4], device='cuda:0')
# label:tensor([7])
# idx:tensor([7], device='cuda:0')
# label:tensor([3])
# idx:tensor([3], device='cuda:0')
# label:tensor([5])
# idx:tensor([5], device='cuda:0')
# label:tensor([3])
# idx:tensor([3], device='cuda:0')
# label:tensor([8])
# idx:tensor([8], device='cuda:0')
# label:tensor([5])
# idx:tensor([5], device='cuda:0')
# label:tensor([0])
# idx:tensor([0], device='cuda:0')
# label:tensor([2])
# idx:tensor([2], device='cuda:0')
# label:tensor([1])
# idx:tensor([1], device='cuda:0')
# label:tensor([6])
# idx:tensor([6], device='cuda:0')
# label:tensor([4])
# idx:tensor([3], device='cuda:0')
# label:tensor([3])
# idx:tensor([3], device='cuda:0')
# label:tensor([3])
# idx:tensor([3], device='cuda:0')
# label:tensor([9])
# idx:tensor([9], device='cuda:0')
# label:tensor([6])
# idx:tensor([6], device='cuda:0')
# label:tensor([9])
# idx:tensor([9], device='cuda:0')
# label:tensor([8])
# idx:tensor([8], device='cuda:0')
# label:tensor([8])
# idx:tensor([8], device='cuda:0')
# label:tensor([5])
# idx:tensor([5], device='cuda:0')
# label:tensor([8])
# idx:tensor([9], device='cuda:0')
# label:tensor([6])
# idx:tensor([6], device='cuda:0')
# label:tensor([6])
# idx:tensor([6], device='cuda:0')
# label:tensor([2])
# idx:tensor([2], device='cuda:0')
# label:tensor([1])
# idx:tensor([1], device='cuda:0')
# label:tensor([7])
# idx:tensor([7], device='cuda:0')
# label:tensor([7])
# idx:tensor([1], device='cuda:0')
# label:tensor([1])
# idx:tensor([1], device='cuda:0')
# label:tensor([2])
# idx:tensor([2], device='cuda:0')
# label:tensor([7])
# idx:tensor([7], device='cuda:0')
# label:tensor([9])
# idx:tensor([9], device='cuda:0')
# label:tensor([9])
# idx:tensor([9], device='cuda:0')
# label:tensor([4])
# idx:tensor([4], device='cuda:0')
# label:tensor([4])
# idx:tensor([7], device='cuda:0')
# label:tensor([1])
# idx:tensor([1], device='cuda:0')
# label:tensor([2])
# idx:tensor([2], device='cuda:0')
# label:tensor([5])
# idx:tensor([2], device='cuda:0')
# label:tensor([6])
# idx:tensor([3], device='cuda:0')
# label:tensor([8])
# idx:tensor([8], device='cuda:0')
# label:tensor([7])
# idx:tensor([4], device='cuda:0')
# label:tensor([6])
# idx:tensor([6], device='cuda:0')
# label:tensor([8])
# idx:tensor([8], device='cuda:0')
# label:tensor([3])
# idx:tensor([3], device='cuda:0')
# label:tensor([0])
# idx:tensor([0], device='cuda:0')
# label:tensor([5])
# idx:tensor([3], device='cuda:0')
# label:tensor([5])
# idx:tensor([3], device='cuda:0')
# label:tensor([3])
# idx:tensor([6], device='cuda:0')
# label:tensor([0])
# idx:tensor([0], device='cuda:0')
# label:tensor([7])
# idx:tensor([7], device='cuda:0')
# label:tensor([9])
# idx:tensor([9], device='cuda:0')
# label:tensor([1])
# idx:tensor([9], device='cuda:0')
# label:tensor([3])
# idx:tensor([3], device='cuda:0')
# label:tensor([4])
# idx:tensor([2], device='cuda:0')
# label:tensor([4])
# idx:tensor([4], device='cuda:0')
# label:tensor([5])
# idx:tensor([5], device='cuda:0')
# label:tensor([3])
# idx:tensor([3], device='cuda:0')
# label:tensor([9])
# idx:tensor([9], device='cuda:0')
# label:tensor([5])
# idx:tensor([5], device='cuda:0')
# label:tensor([6])
# idx:tensor([6], device='cuda:0')
# label:tensor([9])
# idx:tensor([9], device='cuda:0')
# label:tensor([2])
# idx:tensor([4], device='cuda:0')
# label:tensor([1])
# idx:tensor([1], device='cuda:0')
# label:tensor([1])
# idx:tensor([1], device='cuda:0')
# label:tensor([4])
# idx:tensor([4], device='cuda:0')
# label:tensor([1])
# idx:tensor([1], device='cuda:0')
# label:tensor([9])
# idx:tensor([9], device='cuda:0')
# label:tensor([4])
# idx:tensor([4], device='cuda:0')
# label:tensor([7])
# idx:tensor([7], device='cuda:0')
# label:tensor([6])
# idx:tensor([6], device='cuda:0')
# label:tensor([3])
# idx:tensor([3], device='cuda:0')
# label:tensor([8])
# idx:tensor([0], device='cuda:0')
# label:tensor([9])
# idx:tensor([9], device='cuda:0')
# label:tensor([0])
# idx:tensor([0], device='cuda:0')
# label:tensor([1])
# idx:tensor([9], device='cuda:0')
# label:tensor([3])
# idx:tensor([3], device='cuda:0')
# label:tensor([6])
# idx:tensor([6], device='cuda:0')
# label:tensor([3])
# idx:tensor([5], device='cuda:0')
# label:tensor([6])
# idx:tensor([6], device='cuda:0')
# label:tensor([3])
# idx:tensor([3], device='cuda:0')
# label:tensor([2])
# idx:tensor([6], device='cuda:0')
# label:tensor([0])
# idx:tensor([0], device='cuda:0')
# label:tensor([3])
# idx:tensor([6], device='cuda:0')
# label:tensor([1])
# idx:tensor([1], device='cuda:0')
# label:tensor([0])
# idx:tensor([9], device='cuda:0')
# label:tensor([5])
# idx:tensor([5], device='cuda:0')
# label:tensor([9])
# idx:tensor([9], device='cuda:0')
# label:tensor([6])
# idx:tensor([6], device='cuda:0')
# label:tensor([4])
# idx:tensor([7], device='cuda:0')
# label:tensor([8])
# idx:tensor([1], device='cuda:0')
# label:tensor([9])
# idx:tensor([9], device='cuda:0')
# label:tensor([6])
# idx:tensor([2], device='cuda:0')
# label:tensor([9])
# idx:tensor([9], device='cuda:0')
# label:tensor([6])
# idx:tensor([6], device='cuda:0')
# label:tensor([3])
# idx:tensor([3], device='cuda:0')
# label:tensor([0])
# idx:tensor([0], device='cuda:0')
# label:tensor([3])
# idx:tensor([3], device='cuda:0')
# label:tensor([2])
# idx:tensor([2], device='cuda:0')
# label:tensor([2])
# idx:tensor([2], device='cuda:0')
# label:tensor([7])
# idx:tensor([7], device='cuda:0')
# label:tensor([8])
# idx:tensor([8], device='cuda:0')
# label:tensor([3])
# idx:tensor([3], device='cuda:0')
# label:tensor([8])
# idx:tensor([8], device='cuda:0')
# label:tensor([2])
# idx:tensor([2], device='cuda:0')
# label:tensor([7])
# idx:tensor([7], device='cuda:0')
# label:tensor([5])
# idx:tensor([5], device='cuda:0')
# label:tensor([7])
# idx:tensor([7], device='cuda:0')
# label:tensor([2])
# idx:tensor([2], device='cuda:0')
# label:tensor([4])
# idx:tensor([4], device='cuda:0')
# label:tensor([8])
# idx:tensor([8], device='cuda:0')
# label:tensor([7])
# idx:tensor([7], device='cuda:0')
# label:tensor([4])
# idx:tensor([4], device='cuda:0')
# label:tensor([2])
# idx:tensor([2], device='cuda:0')
# label:tensor([9])
# idx:tensor([9], device='cuda:0')
# label:tensor([8])
# idx:tensor([9], device='cuda:0')
# label:tensor([8])
# idx:tensor([8], device='cuda:0')
# label:tensor([6])
# idx:tensor([6], device='cuda:0')
# label:tensor([8])
# idx:tensor([8], device='cuda:0')
# label:tensor([8])
# idx:tensor([8], device='cuda:0')
# label:tensor([7])
# idx:tensor([2], device='cuda:0')
# label:tensor([4])
# idx:tensor([4], device='cuda:0')
# label:tensor([3])
# idx:tensor([3], device='cuda:0')
# label:tensor([3])
# idx:tensor([3], device='cuda:0')
# label:tensor([8])
# idx:tensor([9], device='cuda:0')
# label:tensor([4])
# idx:tensor([4], device='cuda:0')
# label:tensor([9])
# idx:tensor([9], device='cuda:0')
# label:tensor([4])
# idx:tensor([4], device='cuda:0')
# label:tensor([8])
# idx:tensor([8], device='cuda:0')
# label:tensor([8])
# idx:tensor([8], device='cuda:0')
# label:tensor([1])
# idx:tensor([1], device='cuda:0')
# label:tensor([8])
# idx:tensor([8], device='cuda:0')
# label:tensor([2])
# idx:tensor([0], device='cuda:0')
# label:tensor([1])
# idx:tensor([1], device='cuda:0')
# label:tensor([3])
# idx:tensor([3], device='cuda:0')
# label:tensor([6])
# idx:tensor([3], device='cuda:0')
# label:tensor([5])
# idx:tensor([5], device='cuda:0')
# label:tensor([4])
# idx:tensor([4], device='cuda:0')
# label:tensor([2])
# idx:tensor([0], device='cuda:0')
# label:tensor([7])
# idx:tensor([7], device='cuda:0')
# label:tensor([9])
# idx:tensor([9], device='cuda:0')
# label:tensor([9])
# idx:tensor([8], device='cuda:0')
# label:tensor([4])
# idx:tensor([2], device='cuda:0')
# label:tensor([1])
# idx:tensor([1], device='cuda:0')
# label:tensor([4])
# idx:tensor([2], device='cuda:0')
# label:tensor([1])
# idx:tensor([1], device='cuda:0')
# label:tensor([3])
# idx:tensor([7], device='cuda:0')
# label:tensor([2])
# idx:tensor([2], device='cuda:0')
# label:tensor([7])
# idx:tensor([7], device='cuda:0')
# label:tensor([0])
# idx:tensor([0], device='cuda:0')
# label:tensor([7])
# idx:tensor([7], device='cuda:0')
# label:tensor([9])
# idx:tensor([1], device='cuda:0')
# label:tensor([7])
# idx:tensor([7], device='cuda:0')
# label:tensor([6])
# idx:tensor([6], device='cuda:0')
# label:tensor([6])
# idx:tensor([6], device='cuda:0')
# label:tensor([2])
# idx:tensor([2], device='cuda:0')
# label:tensor([5])
# idx:tensor([3], device='cuda:0')
# label:tensor([9])
# idx:tensor([9], device='cuda:0')
# label:tensor([2])
# idx:tensor([0], device='cuda:0')
# label:tensor([9])
# idx:tensor([9], device='cuda:0')
# label:tensor([1])
# idx:tensor([1], device='cuda:0')
# label:tensor([2])
# idx:tensor([2], device='cuda:0')
# label:tensor([2])
# idx:tensor([2], device='cuda:0')
# label:tensor([6])
# idx:tensor([6], device='cuda:0')
# label:tensor([8])
# idx:tensor([8], device='cuda:0')
# label:tensor([2])
# idx:tensor([2], device='cuda:0')
# label:tensor([1])
# idx:tensor([1], device='cuda:0')
# label:tensor([3])
# idx:tensor([3], device='cuda:0')
# label:tensor([6])
# idx:tensor([3], device='cuda:0')
# label:tensor([6])
# idx:tensor([6], device='cuda:0')
# label:tensor([0])
# idx:tensor([0], device='cuda:0')
# label:tensor([1])
# idx:tensor([1], device='cuda:0')
# label:tensor([2])
# idx:tensor([2], device='cuda:0')
# label:tensor([7])
# idx:tensor([7], device='cuda:0')
# label:tensor([0])
# idx:tensor([9], device='cuda:0')
# label:tensor([5])
# idx:tensor([2], device='cuda:0')
# label:tensor([4])
# idx:tensor([4], device='cuda:0')
# label:tensor([6])
# idx:tensor([6], device='cuda:0')
# label:tensor([1])
# idx:tensor([1], device='cuda:0')
# label:tensor([6])
# idx:tensor([6], device='cuda:0')
# label:tensor([4])
# idx:tensor([6], device='cuda:0')
# label:tensor([0])
# idx:tensor([0], device='cuda:0')
# label:tensor([2])
# idx:tensor([2], device='cuda:0')
# label:tensor([2])
# idx:tensor([2], device='cuda:0')
# label:tensor([6])
# idx:tensor([6], device='cuda:0')
# label:tensor([0])
# idx:tensor([0], device='cuda:0')
# label:tensor([5])
# idx:tensor([6], device='cuda:0')
# label:tensor([9])
# idx:tensor([9], device='cuda:0')
# label:tensor([1])
# idx:tensor([1], device='cuda:0')
# label:tensor([7])
# idx:tensor([7], device='cuda:0')
# label:tensor([6])
# idx:tensor([6], device='cuda:0')
# label:tensor([7])
# idx:tensor([7], device='cuda:0')
# label:tensor([0])
# idx:tensor([8], device='cuda:0')
# label:tensor([3])
# idx:tensor([3], device='cuda:0')
# label:tensor([9])
# idx:tensor([9], device='cuda:0')
# label:tensor([6])
# idx:tensor([6], device='cuda:0')
# label:tensor([8])
# idx:tensor([8], device='cuda:0')
# label:tensor([3])
# idx:tensor([3], device='cuda:0')
# label:tensor([0])
# idx:tensor([0], device='cuda:0')
# label:tensor([3])
# idx:tensor([3], device='cuda:0')
# label:tensor([4])
# idx:tensor([4], device='cuda:0')
# label:tensor([7])
# idx:tensor([4], device='cuda:0')
# label:tensor([7])
# idx:tensor([5], device='cuda:0')
# label:tensor([1])
# idx:tensor([1], device='cuda:0')
# label:tensor([4])
# idx:tensor([3], device='cuda:0')
# label:tensor([7])
# idx:tensor([7], device='cuda:0')
# label:tensor([2])
# idx:tensor([2], device='cuda:0')
# label:tensor([7])
# idx:tensor([7], device='cuda:0')
# label:tensor([1])
# idx:tensor([1], device='cuda:0')
# label:tensor([4])
# idx:tensor([2], device='cuda:0')
# label:tensor([7])
# idx:tensor([7], device='cuda:0')
# label:tensor([4])
# idx:tensor([4], device='cuda:0')
# label:tensor([4])
# idx:tensor([4], device='cuda:0')
# label:tensor([8])
# idx:tensor([8], device='cuda:0')
# label:tensor([4])
# idx:tensor([4], device='cuda:0')
# label:tensor([7])
# idx:tensor([2], device='cuda:0')
# label:tensor([7])
# idx:tensor([7], device='cuda:0')
# label:tensor([5])
# idx:tensor([3], device='cuda:0')
# label:tensor([3])
# idx:tensor([5], device='cuda:0')
# label:tensor([7])
# idx:tensor([7], device='cuda:0')
# label:tensor([2])
# idx:tensor([2], device='cuda:0')
# label:tensor([0])
# idx:tensor([1], device='cuda:0')
# label:tensor([8])
# idx:tensor([8], device='cuda:0')
# label:tensor([9])
# idx:tensor([9], device='cuda:0')
# label:tensor([5])
# idx:tensor([4], device='cuda:0')
# label:tensor([8])
# idx:tensor([1], device='cuda:0')
# label:tensor([3])
# idx:tensor([3], device='cuda:0')
# label:tensor([6])
# idx:tensor([6], device='cuda:0')
# label:tensor([2])
# idx:tensor([2], device='cuda:0')
# label:tensor([0])
# idx:tensor([0], device='cuda:0')
# label:tensor([8])
# idx:tensor([8], device='cuda:0')
# label:tensor([7])
# idx:tensor([7], device='cuda:0')
# label:tensor([3])
# idx:tensor([3], device='cuda:0')
# label:tensor([7])
# idx:tensor([7], device='cuda:0')
# label:tensor([6])
# idx:tensor([6], device='cuda:0')
# label:tensor([5])
# idx:tensor([5], device='cuda:0')
# label:tensor([3])
# idx:tensor([3], device='cuda:0')
# label:tensor([1])
# idx:tensor([1], device='cuda:0')
# label:tensor([3])
# idx:tensor([3], device='cuda:0')
# label:tensor([2])
# idx:tensor([2], device='cuda:0')
# label:tensor([2])
# idx:tensor([5], device='cuda:0')
# label:tensor([5])
# idx:tensor([5], device='cuda:0')
# label:tensor([4])
# idx:tensor([4], device='cuda:0')
# label:tensor([1])
# idx:tensor([9], device='cuda:0')
# label:tensor([2])
# idx:tensor([4], device='cuda:0')
# label:tensor([9])
# idx:tensor([9], device='cuda:0')
# label:tensor([2])
# idx:tensor([2], device='cuda:0')
# label:tensor([7])
# idx:tensor([7], device='cuda:0')
# label:tensor([0])
# idx:tensor([8], device='cuda:0')
# label:tensor([7])
# idx:tensor([7], device='cuda:0')
# label:tensor([2])
# idx:tensor([2], device='cuda:0')
# label:tensor([1])
# idx:tensor([1], device='cuda:0')
# label:tensor([3])
# idx:tensor([2], device='cuda:0')
# label:tensor([2])
# idx:tensor([2], device='cuda:0')
# label:tensor([0])
# idx:tensor([0], device='cuda:0')
# label:tensor([2])
# idx:tensor([2], device='cuda:0')
# label:tensor([4])
# idx:tensor([4], device='cuda:0')
# label:tensor([7])
# idx:tensor([3], device='cuda:0')
# label:tensor([9])
# idx:tensor([9], device='cuda:0')
# label:tensor([8])
# idx:tensor([8], device='cuda:0')
# label:tensor([9])
# idx:tensor([1], device='cuda:0')
# label:tensor([0])
# idx:tensor([0], device='cuda:0')
# label:tensor([7])
# idx:tensor([5], device='cuda:0')
# label:tensor([7])
# idx:tensor([2], device='cuda:0')
# label:tensor([0])
# idx:tensor([0], device='cuda:0')
# label:tensor([7])
# idx:tensor([7], device='cuda:0')
# label:tensor([8])
# idx:tensor([8], device='cuda:0')
# label:tensor([4])
# idx:tensor([4], device='cuda:0')
# label:tensor([6])
# idx:tensor([6], device='cuda:0')
# label:tensor([3])
# idx:tensor([6], device='cuda:0')
# label:tensor([3])
# idx:tensor([5], device='cuda:0')
# label:tensor([0])
# idx:tensor([0], device='cuda:0')
# label:tensor([1])
# idx:tensor([1], device='cuda:0')
# label:tensor([3])
# idx:tensor([3], device='cuda:0')
# label:tensor([7])
# idx:tensor([7], device='cuda:0')
# label:tensor([0])
# idx:tensor([0], device='cuda:0')
# label:tensor([1])
# idx:tensor([1], device='cuda:0')
# label:tensor([3])
# idx:tensor([3], device='cuda:0')
# label:tensor([1])
# idx:tensor([1], device='cuda:0')
# label:tensor([4])
# idx:tensor([4], device='cuda:0')
# label:tensor([2])
# idx:tensor([2], device='cuda:0')
# label:tensor([3])
# idx:tensor([3], device='cuda:0')
# label:tensor([8])
# idx:tensor([8], device='cuda:0')
# label:tensor([4])
# idx:tensor([4], device='cuda:0')
# label:tensor([2])
# idx:tensor([5], device='cuda:0')
# label:tensor([3])
# idx:tensor([3], device='cuda:0')
# label:tensor([7])
# idx:tensor([7], device='cuda:0')
# label:tensor([8])
# idx:tensor([8], device='cuda:0')
# label:tensor([4])
# idx:tensor([4], device='cuda:0')
# label:tensor([3])
# idx:tensor([2], device='cuda:0')
# label:tensor([0])
# idx:tensor([1], device='cuda:0')
# label:tensor([9])
# idx:tensor([9], device='cuda:0')
# label:tensor([0])
# idx:tensor([0], device='cuda:0')
# label:tensor([0])
# idx:tensor([9], device='cuda:0')
# label:tensor([1])
# idx:tensor([1], device='cuda:0')
# label:tensor([0])
# idx:tensor([8], device='cuda:0')
# label:tensor([4])
# idx:tensor([6], device='cuda:0')
# label:tensor([4])
# idx:tensor([4], device='cuda:0')
# label:tensor([6])
# idx:tensor([6], device='cuda:0')
# label:tensor([7])
# idx:tensor([7], device='cuda:0')
# label:tensor([6])
# idx:tensor([3], device='cuda:0')
# label:tensor([1])
# idx:tensor([1], device='cuda:0')
# label:tensor([1])
# idx:tensor([1], device='cuda:0')
# label:tensor([3])
# idx:tensor([3], device='cuda:0')
# label:tensor([7])
# idx:tensor([7], device='cuda:0')
# label:tensor([3])
# idx:tensor([3], device='cuda:0')
# label:tensor([5])
# idx:tensor([5], device='cuda:0')
# label:tensor([2])
# idx:tensor([3], device='cuda:0')
# label:tensor([6])
# idx:tensor([6], device='cuda:0')
# label:tensor([6])
# idx:tensor([6], device='cuda:0')
# label:tensor([5])
# idx:tensor([5], device='cuda:0')
# label:tensor([8])
# idx:tensor([8], device='cuda:0')
# label:tensor([7])
# idx:tensor([3], device='cuda:0')
# label:tensor([1])
# idx:tensor([1], device='cuda:0')
# label:tensor([6])
# idx:tensor([6], device='cuda:0')
# label:tensor([8])
# idx:tensor([8], device='cuda:0')
# label:tensor([8])
# idx:tensor([8], device='cuda:0')
# label:tensor([5])
# idx:tensor([3], device='cuda:0')
# label:tensor([3])
# idx:tensor([3], device='cuda:0')
# label:tensor([0])
# idx:tensor([0], device='cuda:0')
# label:tensor([4])
# idx:tensor([4], device='cuda:0')
# label:tensor([0])
# idx:tensor([2], device='cuda:0')
# label:tensor([1])
# idx:tensor([1], device='cuda:0')
# label:tensor([3])
# idx:tensor([5], device='cuda:0')
# label:tensor([8])
# idx:tensor([8], device='cuda:0')
# label:tensor([8])
# idx:tensor([8], device='cuda:0')
# label:tensor([0])
# idx:tensor([0], device='cuda:0')
# label:tensor([6])
# idx:tensor([6], device='cuda:0')
# label:tensor([9])
# idx:tensor([9], device='cuda:0')
# label:tensor([9])
# idx:tensor([9], device='cuda:0')
# label:tensor([9])
# idx:tensor([9], device='cuda:0')
# label:tensor([5])
# idx:tensor([1], device='cuda:0')
# label:tensor([5])
# idx:tensor([3], device='cuda:0')
# label:tensor([8])
# idx:tensor([2], device='cuda:0')
# label:tensor([6])
# idx:tensor([6], device='cuda:0')
# label:tensor([0])
# idx:tensor([2], device='cuda:0')
# label:tensor([0])
# idx:tensor([8], device='cuda:0')
# label:tensor([4])
# idx:tensor([4], device='cuda:0')
# label:tensor([2])
# idx:tensor([2], device='cuda:0')
# label:tensor([3])
# idx:tensor([3], device='cuda:0')
# label:tensor([2])
# idx:tensor([2], device='cuda:0')
# label:tensor([7])
# idx:tensor([7], device='cuda:0')
# label:tensor([2])
# idx:tensor([2], device='cuda:0')
# label:tensor([2])
# idx:tensor([2], device='cuda:0')
# label:tensor([5])
# idx:tensor([5], device='cuda:0')
# label:tensor([9])
# idx:tensor([9], device='cuda:0')
# label:tensor([8])
# idx:tensor([8], device='cuda:0')
# label:tensor([9])
# idx:tensor([9], device='cuda:0')
# ...
# label:tensor([1])
# idx:tensor([1], device='cuda:0')
# label:tensor([2])
# idx:tensor([2], device='cuda:0')
# label:tensor([9])
# idx:tensor([9], device='cuda:0')
# label:tensor([4])
# idx:tensor([2], device='cuda:0')
# label:tensor([6])
# idx:tensor([6], device='cuda:0')
# label:tensor([9])
# idx:tensor([9], device='cuda:0')
# label:tensor([6])
# idx:tensor([6], device='cuda:0')
# label:tensor([1])
# idx:tensor([4], device='cuda:0')
# label:tensor([0])
# idx:tensor([0], device='cuda:0')
# label:tensor([1])
# idx:tensor([1], device='cuda:0')
# label:tensor([8])
# idx:tensor([8], device='cuda:0')
# label:tensor([7])
# idx:tensor([7], device='cuda:0')
# label:tensor([0])
# idx:tensor([1], device='cuda:0')
# label:tensor([0])
# idx:tensor([0], device='cuda:0')
# label:tensor([4])
# idx:tensor([4], device='cuda:0')
# label:tensor([7])
# idx:tensor([7], device='cuda:0')
# label:tensor([4])
# idx:tensor([4], device='cuda:0')
# label:tensor([2])
# idx:tensor([3], device='cuda:0')
# label:tensor([6])
# idx:tensor([6], device='cuda:0')
# label:tensor([9])
# idx:tensor([9], device='cuda:0')
# label:tensor([5])
# idx:tensor([5], device='cuda:0')
# label:tensor([9])
# idx:tensor([9], device='cuda:0')
# label:tensor([0])
# idx:tensor([4], device='cuda:0')
# label:tensor([7])
# idx:tensor([7], device='cuda:0')
# label:tensor([4])
# idx:tensor([4], device='cuda:0')
# label:tensor([5])
# idx:tensor([5], device='cuda:0')
# label:tensor([8])
# idx:tensor([8], device='cuda:0')
# label:tensor([1])
# idx:tensor([1], device='cuda:0')
# label:tensor([4])
# idx:tensor([4], device='cuda:0')
# label:tensor([7])
# idx:tensor([4], device='cuda:0')
# label:tensor([9])
# idx:tensor([9], device='cuda:0')
# label:tensor([9])
# idx:tensor([9], device='cuda:0')
# label:tensor([8])
# idx:tensor([8], device='cuda:0')
# label:tensor([8])
# idx:tensor([8], device='cuda:0')
# label:tensor([6])
# idx:tensor([6], device='cuda:0')
# label:tensor([3])
# idx:tensor([1], device='cuda:0')
# label:tensor([7])
# idx:tensor([7], device='cuda:0')
# label:tensor([0])
# idx:tensor([0], device='cuda:0')
# label:tensor([8])
# idx:tensor([7], device='cuda:0')
# label:tensor([9])
# idx:tensor([9], device='cuda:0')
# label:tensor([6])
# idx:tensor([1], device='cuda:0')
# label:tensor([2])
# idx:tensor([2], device='cuda:0')
# label:tensor([4])
# idx:tensor([6], device='cuda:0')
# label:tensor([6])
# idx:tensor([6], device='cuda:0')
# label:tensor([2])
# idx:tensor([2], device='cuda:0')
# label:tensor([9])
# idx:tensor([9], device='cuda:0')
# label:tensor([7])
# idx:tensor([7], device='cuda:0')
# label:tensor([4])
# idx:tensor([4], device='cuda:0')
# label:tensor([6])
# idx:tensor([6], device='cuda:0')
# label:tensor([8])
# idx:tensor([8], device='cuda:0')
# label:tensor([5])
# idx:tensor([5], device='cuda:0')
# label:tensor([6])
# idx:tensor([6], device='cuda:0')
# label:tensor([1])
# idx:tensor([1], device='cuda:0')
# label:tensor([3])
# idx:tensor([2], device='cuda:0')
# label:tensor([5])
# idx:tensor([9], device='cuda:0')
# label:tensor([9])
# idx:tensor([9], device='cuda:0')
# label:tensor([9])
# idx:tensor([9], device='cuda:0')
# label:tensor([1])
# idx:tensor([9], device='cuda:0')
# label:tensor([3])
# idx:tensor([3], device='cuda:0')
# label:tensor([2])
# idx:tensor([3], device='cuda:0')
# label:tensor([0])
# idx:tensor([0], device='cuda:0')
# label:tensor([3])
# idx:tensor([3], device='cuda:0')
# label:tensor([0])
# idx:tensor([0], device='cuda:0')
# label:tensor([2])
# idx:tensor([6], device='cuda:0')
# label:tensor([0])
# idx:tensor([1], device='cuda:0')
# label:tensor([7])
# idx:tensor([2], device='cuda:0')
# label:tensor([3])
# idx:tensor([5], device='cuda:0')
# label:tensor([9])
# idx:tensor([9], device='cuda:0')
# label:tensor([3])
# idx:tensor([6], device='cuda:0')
# label:tensor([5])
# idx:tensor([5], device='cuda:0')
# label:tensor([7])
# idx:tensor([7], device='cuda:0')
# label:tensor([6])
# idx:tensor([2], device='cuda:0')
# label:tensor([5])
# idx:tensor([5], device='cuda:0')
# label:tensor([9])
# idx:tensor([9], device='cuda:0')
# label:tensor([5])
# idx:tensor([5], device='cuda:0')
# label:tensor([6])
# idx:tensor([6], device='cuda:0')
# label:tensor([1])
# idx:tensor([1], device='cuda:0')
# label:tensor([2])
# idx:tensor([2], device='cuda:0')
# label:tensor([4])
# idx:tensor([4], device='cuda:0')
# label:tensor([0])
# idx:tensor([0], device='cuda:0')
# label:tensor([2])
# idx:tensor([2], device='cuda:0')
# label:tensor([7])
# idx:tensor([7], device='cuda:0')
# label:tensor([8])
# idx:tensor([8], device='cuda:0')
# label:tensor([4])
# idx:tensor([4], device='cuda:0')
# label:tensor([4])
# idx:tensor([4], device='cuda:0')
# label:tensor([0])
# idx:tensor([0], device='cuda:0')
# label:tensor([9])
# idx:tensor([9], device='cuda:0')
# label:tensor([5])
# idx:tensor([5], device='cuda:0')
# label:tensor([9])
# idx:tensor([9], device='cuda:0')
# label:tensor([2])
# idx:tensor([6], device='cuda:0')
# label:tensor([9])
# idx:tensor([9], device='cuda:0')
# label:tensor([3])
# idx:tensor([3], device='cuda:0')
# label:tensor([2])
# idx:tensor([2], device='cuda:0')
# label:tensor([4])
# idx:tensor([4], device='cuda:0')
# label:tensor([3])
# idx:tensor([3], device='cuda:0')
# label:tensor([2])
# idx:tensor([2], device='cuda:0')
# label:tensor([2])
# idx:tensor([6], device='cuda:0')
# label:tensor([8])
# idx:tensor([8], device='cuda:0')
# label:tensor([8])
# idx:tensor([8], device='cuda:0')
# label:tensor([6])
# idx:tensor([6], device='cuda:0')
# label:tensor([8])
# idx:tensor([6], device='cuda:0')
# label:tensor([1])
# idx:tensor([1], device='cuda:0')
# label:tensor([6])
# idx:tensor([6], device='cuda:0')
# label:tensor([8])
# idx:tensor([8], device='cuda:0')
# label:tensor([9])
# idx:tensor([9], device='cuda:0')
# label:tensor([8])
# idx:tensor([8], device='cuda:0')
# label:tensor([2])
# idx:tensor([2], device='cuda:0')
# label:tensor([1])
# idx:tensor([1], device='cuda:0')
# label:tensor([4])
# idx:tensor([4], device='cuda:0')
# label:tensor([9])
# idx:tensor([9], device='cuda:0')
# label:tensor([1])
# idx:tensor([1], device='cuda:0')
# label:tensor([5])
# idx:tensor([5], device='cuda:0')
# label:tensor([7])
# idx:tensor([7], device='cuda:0')
# label:tensor([1])
# idx:tensor([1], device='cuda:0')
# label:tensor([6])
# idx:tensor([3], device='cuda:0')
# label:tensor([0])
# idx:tensor([0], device='cuda:0')
# label:tensor([1])
# idx:tensor([1], device='cuda:0')
# label:tensor([5])
# idx:tensor([5], device='cuda:0')
# label:tensor([2])
# idx:tensor([2], device='cuda:0')
# label:tensor([8])
# idx:tensor([8], device='cuda:0')
# label:tensor([1])
# idx:tensor([1], device='cuda:0')
# label:tensor([1])
# idx:tensor([1], device='cuda:0')
# label:tensor([3])
# idx:tensor([3], device='cuda:0')
# label:tensor([8])
# idx:tensor([8], device='cuda:0')
# label:tensor([1])
# idx:tensor([1], device='cuda:0')
# label:tensor([3])
# idx:tensor([8], device='cuda:0')
# label:tensor([1])
# idx:tensor([1], device='cuda:0')
# label:tensor([8])
# idx:tensor([8], device='cuda:0')
# label:tensor([5])
# idx:tensor([5], device='cuda:0')
# label:tensor([1])
# idx:tensor([1], device='cuda:0')
# label:tensor([9])
# idx:tensor([1], device='cuda:0')
# label:tensor([0])
# idx:tensor([0], device='cuda:0')
# label:tensor([3])
# idx:tensor([5], device='cuda:0')
# label:tensor([0])
# idx:tensor([0], device='cuda:0')
# label:tensor([4])
# idx:tensor([4], device='cuda:0')
# label:tensor([0])
# idx:tensor([0], device='cuda:0')
# label:tensor([5])
# idx:tensor([5], device='cuda:0')
# label:tensor([1])
# idx:tensor([9], device='cuda:0')
# label:tensor([2])
# idx:tensor([2], device='cuda:0')
# label:tensor([0])
# idx:tensor([0], device='cuda:0')
# label:tensor([4])
# idx:tensor([4], device='cuda:0')
# label:tensor([9])
# idx:tensor([9], device='cuda:0')
# label:tensor([5])
# idx:tensor([5], device='cuda:0')
# label:tensor([1])
# idx:tensor([1], device='cuda:0')
# label:tensor([2])
# idx:tensor([2], device='cuda:0')
# label:tensor([2])
# idx:tensor([4], device='cuda:0')
# label:tensor([7])
# idx:tensor([7], device='cuda:0')
# label:tensor([8])
# idx:tensor([8], device='cuda:0')
# label:tensor([7])
# idx:tensor([4], device='cuda:0')
# label:tensor([2])
# idx:tensor([2], device='cuda:0')
# label:tensor([4])
# idx:tensor([4], device='cuda:0')
# label:tensor([5])
# idx:tensor([5], device='cuda:0')
# label:tensor([3])
# idx:tensor([3], device='cuda:0')
# label:tensor([4])
# idx:tensor([4], device='cuda:0')
# label:tensor([0])
# idx:tensor([0], device='cuda:0')
# label:tensor([6])
# idx:tensor([4], device='cuda:0')
# label:tensor([1])
# idx:tensor([1], device='cuda:0')
# label:tensor([5])
# idx:tensor([5], device='cuda:0')
# label:tensor([9])
# idx:tensor([9], device='cuda:0')
# label:tensor([8])
# idx:tensor([8], device='cuda:0')
# label:tensor([0])
# idx:tensor([8], device='cuda:0')
# label:tensor([2])
# idx:tensor([2], device='cuda:0')
# label:tensor([0])
# idx:tensor([2], device='cuda:0')
# label:tensor([7])
# idx:tensor([4], device='cuda:0')
# label:tensor([6])
# idx:tensor([6], device='cuda:0')
# label:tensor([0])
# idx:tensor([8], device='cuda:0')
# label:tensor([5])
# idx:tensor([5], device='cuda:0')
# label:tensor([9])
# idx:tensor([9], device='cuda:0')
# label:tensor([7])
# idx:tensor([7], device='cuda:0')
# label:tensor([5])
# idx:tensor([5], device='cuda:0')
# label:tensor([0])
# idx:tensor([9], device='cuda:0')
# label:tensor([4])
# idx:tensor([4], device='cuda:0')
# label:tensor([6])
# idx:tensor([4], device='cuda:0')
# label:tensor([0])
# idx:tensor([2], device='cuda:0')
# label:tensor([6])
# idx:tensor([6], device='cuda:0')
# label:tensor([3])
# idx:tensor([3], device='cuda:0')
# label:tensor([6])
# idx:tensor([6], device='cuda:0')
# label:tensor([8])
# idx:tensor([0], device='cuda:0')
# label:tensor([1])
# idx:tensor([1], device='cuda:0')
# label:tensor([1])
# idx:tensor([9], device='cuda:0')
# label:tensor([8])
# idx:tensor([8], device='cuda:0')
# label:tensor([9])
# idx:tensor([9], device='cuda:0')
# label:tensor([7])
# idx:tensor([7], device='cuda:0')
# label:tensor([2])
# idx:tensor([2], device='cuda:0')
# label:tensor([9])
# idx:tensor([9], device='cuda:0')
# label:tensor([0])
# idx:tensor([0], device='cuda:0')
# label:tensor([2])
# idx:tensor([2], device='cuda:0')
# label:tensor([2])
# idx:tensor([2], device='cuda:0')
# label:tensor([9])
# idx:tensor([9], device='cuda:0')
# label:tensor([0])
# idx:tensor([0], device='cuda:0')
# label:tensor([6])
# idx:tensor([6], device='cuda:0')
# label:tensor([5])
# idx:tensor([2], device='cuda:0')
# label:tensor([7])
# idx:tensor([7], device='cuda:0')
# label:tensor([7])
# idx:tensor([7], device='cuda:0')
# label:tensor([9])
# idx:tensor([9], device='cuda:0')
# label:tensor([1])
# idx:tensor([1], device='cuda:0')
# label:tensor([7])
# idx:tensor([7], device='cuda:0')
# label:tensor([9])
# idx:tensor([9], device='cuda:0')
# label:tensor([8])
# idx:tensor([8], device='cuda:0')
# label:tensor([4])
# idx:tensor([4], device='cuda:0')
# label:tensor([5])
# idx:tensor([5], device='cuda:0')
# label:tensor([0])
# idx:tensor([0], device='cuda:0')
# label:tensor([8])
# idx:tensor([8], device='cuda:0')
# label:tensor([0])
# idx:tensor([0], device='cuda:0')
# label:tensor([2])
# idx:tensor([3], device='cuda:0')
# label:tensor([5])
# idx:tensor([3], device='cuda:0')
# label:tensor([2])
# idx:tensor([2], device='cuda:0')
# label:tensor([1])
# idx:tensor([1], device='cuda:0')
# label:tensor([4])
# idx:tensor([4], device='cuda:0')
# label:tensor([4])
# idx:tensor([4], device='cuda:0')
# label:tensor([8])
# idx:tensor([8], device='cuda:0')
# label:tensor([9])
# idx:tensor([9], device='cuda:0')
# label:tensor([7])
# idx:tensor([7], device='cuda:0')
# label:tensor([8])
# idx:tensor([8], device='cuda:0')
# label:tensor([3])
# idx:tensor([1], device='cuda:0')
# label:tensor([6])
# idx:tensor([6], device='cuda:0')
# label:tensor([6])
# idx:tensor([6], device='cuda:0')
# label:tensor([0])
# idx:tensor([0], device='cuda:0')
# label:tensor([1])
# idx:tensor([9], device='cuda:0')
# label:tensor([1])
# idx:tensor([1], device='cuda:0')
# label:tensor([1])
# idx:tensor([1], device='cuda:0')
# label:tensor([8])
# idx:tensor([8], device='cuda:0')
# label:tensor([1])
# idx:tensor([1], device='cuda:0')
# label:tensor([4])
# idx:tensor([7], device='cuda:0')
# label:tensor([4])
# idx:tensor([4], device='cuda:0')
# label:tensor([0])
# idx:tensor([0], device='cuda:0')
# label:tensor([7])
# idx:tensor([7], device='cuda:0')
# label:tensor([8])
# idx:tensor([8], device='cuda:0')
# label:tensor([2])
# idx:tensor([2], device='cuda:0')
# label:tensor([1])
# idx:tensor([1], device='cuda:0')
# label:tensor([2])
# idx:tensor([2], device='cuda:0')
# label:tensor([5])
# idx:tensor([5], device='cuda:0')
# label:tensor([4])
# idx:tensor([4], device='cuda:0')
# label:tensor([6])
# idx:tensor([6], device='cuda:0')
# label:tensor([0])
# idx:tensor([0], device='cuda:0')
# label:tensor([5])
# idx:tensor([5], device='cuda:0')
# label:tensor([7])
# idx:tensor([1], device='cuda:0')
# label:tensor([4])
# idx:tensor([8], device='cuda:0')
# label:tensor([4])
# idx:tensor([4], device='cuda:0')
# label:tensor([3])
# idx:tensor([2], device='cuda:0')
# label:tensor([9])
# idx:tensor([9], device='cuda:0')
# label:tensor([5])
# idx:tensor([6], device='cuda:0')
# label:tensor([8])
# idx:tensor([8], device='cuda:0')
# label:tensor([8])
# idx:tensor([8], device='cuda:0')
# label:tensor([0])
# idx:tensor([0], device='cuda:0')
# label:tensor([8])
# idx:tensor([8], device='cuda:0')
# label:tensor([7])
# idx:tensor([2], device='cuda:0')
# label:tensor([4])
# idx:tensor([4], device='cuda:0')
# label:tensor([1])
# idx:tensor([1], device='cuda:0')
# label:tensor([8])
# idx:tensor([8], device='cuda:0')
# label:tensor([4])
# idx:tensor([4], device='cuda:0')
# label:tensor([9])
# idx:tensor([9], device='cuda:0')
# label:tensor([5])
# idx:tensor([5], device='cuda:0')
# label:tensor([4])
# idx:tensor([3], device='cuda:0')
# label:tensor([1])
# idx:tensor([1], device='cuda:0')
# label:tensor([7])
# idx:tensor([7], device='cuda:0')
# label:tensor([7])
# idx:tensor([7], device='cuda:0')
# label:tensor([7])
# idx:tensor([7], device='cuda:0')
# label:tensor([7])
# idx:tensor([7], device='cuda:0')
# label:tensor([0])
# idx:tensor([0], device='cuda:0')
# label:tensor([3])
# idx:tensor([6], device='cuda:0')
# label:tensor([8])
# idx:tensor([8], device='cuda:0')
# label:tensor([3])
# idx:tensor([3], device='cuda:0')
# label:tensor([3])
# idx:tensor([3], device='cuda:0')
# label:tensor([0])
# idx:tensor([0], device='cuda:0')
# label:tensor([5])
# idx:tensor([5], device='cuda:0')
# label:tensor([7])
# idx:tensor([4], device='cuda:0')
# label:tensor([0])
# idx:tensor([0], device='cuda:0')
# label:tensor([8])
# idx:tensor([8], device='cuda:0')
# label:tensor([0])
# idx:tensor([9], device='cuda:0')
# label:tensor([0])
# idx:tensor([1], device='cuda:0')
# label:tensor([9])
# idx:tensor([9], device='cuda:0')
# label:tensor([2])
# idx:tensor([3], device='cuda:0')
# label:tensor([2])
# idx:tensor([2], device='cuda:0')
# label:tensor([3])
# idx:tensor([3], device='cuda:0')
# label:tensor([4])
# idx:tensor([2], device='cuda:0')
# label:tensor([8])
# idx:tensor([0], device='cuda:0')
# label:tensor([2])
# idx:tensor([6], device='cuda:0')
# label:tensor([2])
# idx:tensor([2], device='cuda:0')
# label:tensor([6])
# idx:tensor([6], device='cuda:0')
# label:tensor([3])
# idx:tensor([4], device='cuda:0')
# label:tensor([3])
# idx:tensor([5], device='cuda:0')
# label:tensor([6])
# idx:tensor([6], device='cuda:0')
# label:tensor([2])
# idx:tensor([2], device='cuda:0')
# label:tensor([9])
# idx:tensor([9], device='cuda:0')
# label:tensor([4])
# idx:tensor([4], device='cuda:0')
# label:tensor([0])
# idx:tensor([0], device='cuda:0')
# label:tensor([1])
# idx:tensor([9], device='cuda:0')
# label:tensor([7])
# idx:tensor([7], device='cuda:0')
# label:tensor([5])
# idx:tensor([5], device='cuda:0')
# label:tensor([5])
# idx:tensor([5], device='cuda:0')
# label:tensor([7])
# idx:tensor([7], device='cuda:0')
# label:tensor([3])
# idx:tensor([5], device='cuda:0')
# label:tensor([0])
# idx:tensor([0], device='cuda:0')
# label:tensor([4])
# idx:tensor([4], device='cuda:0')
# label:tensor([2])
# idx:tensor([6], device='cuda:0')
# label:tensor([0])
# idx:tensor([1], device='cuda:0')
# label:tensor([7])
# idx:tensor([7], device='cuda:0')
# label:tensor([5])
# idx:tensor([3], device='cuda:0')
# label:tensor([8])
# idx:tensor([8], device='cuda:0')
# label:tensor([0])
# idx:tensor([0], device='cuda:0')
# label:tensor([8])
# idx:tensor([8], device='cuda:0')
# label:tensor([2])
# idx:tensor([4], device='cuda:0')
# label:tensor([7])
# idx:tensor([7], device='cuda:0')
# label:tensor([0])
# idx:tensor([0], device='cuda:0')
# label:tensor([3])
# idx:tensor([3], device='cuda:0')
# label:tensor([5])
# idx:tensor([3], device='cuda:0')
# label:tensor([3])
# idx:tensor([3], device='cuda:0')
# label:tensor([8])
# idx:tensor([8], device='cuda:0')
# label:tensor([3])
# idx:tensor([3], device='cuda:0')
# label:tensor([5])
# idx:tensor([5], device='cuda:0')
# label:tensor([1])
# idx:tensor([1], device='cuda:0')
# label:tensor([7])
# idx:tensor([7], device='cuda:0')
# accuracy:0.7986
